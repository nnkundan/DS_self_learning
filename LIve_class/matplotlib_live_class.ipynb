# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#visualization matplot,seaborn,bokeh

# %%
x=np.random.rand(50)
y=np.random.rand(50)

# %%
x*10
# Out:
# array([4.53528171, 4.47421037, 8.76797567, 6.63022085, 7.17730241,
#        8.86358097, 3.09785023, 2.92311552, 4.37467016, 5.99551476,
#        4.94155117, 3.24979116, 3.72114328, 9.21510858, 1.76593859,
#        5.87398592, 5.34345617, 6.19299806, 1.00003338, 5.94820045,
#        3.37653934, 3.53234675, 1.53081368, 2.12382123, 8.53327696,
#        8.75274464, 4.41292785, 9.6424977 , 2.87580606, 1.32309168,
#        2.47700495, 4.90431249, 4.78276625, 2.37058904, 8.66161522,
#        3.68671875, 5.14489977, 8.51503744, 4.22805533, 8.99103305,
#        1.43190106, 3.19064154, 6.11100308, 7.34871746, 9.97118028,
#        0.08471322, 8.04656818, 1.03765219, 2.11866733, 7.31916343])

# %%
y
# Out:
# array([0.39334121, 0.42819252, 0.38448196, 0.36527333, 0.95490243,
#        0.37993503, 0.68427749, 0.48463269, 0.61188753, 0.72686612,
#        0.6229492 , 0.47341283, 0.11688565, 0.26993427, 0.88607226,
#        0.93173045, 0.2018275 , 0.0485031 , 0.08731637, 0.91863026,
#        0.55925926, 0.0497423 , 0.66233943, 0.13826658, 0.17923568,
#        0.64951399, 0.95268932, 0.29452547, 0.40170409, 0.35151181,
#        0.65488876, 0.23570998, 0.26893949, 0.09858881, 0.61849517,
#        0.66319828, 0.06328552, 0.37566941, 0.33936652, 0.9616974 ,
#        0.57769779, 0.48732728, 0.333846  , 0.13506219, 0.5216772 ,
#        0.38476608, 0.70954462, 0.19370589, 0.07375198, 0.01284029])

# %%
plt.scatter(x,y)

# %%
df=pd.DataFrame(np.random.randn(1000),columns=['data'],index=pd.date_range('24-04-2024',periods=1000))

# %%
df.plot(figsize=(20,8))
# Out:
# <Axes: >

# %%
#lineplot
x=[1,2,3,4,5]
y=[5,1,7,2,8]
plt.plot(x,y)
plt.title("Line cchart")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
#lineplot
x=[1,2,3,4,5]
y=[5,1,7,2,8]
plt.title("Line cchart")
plt.xlabel("x")
plt.ylabel("y")

plt.plot(x, y, color = "g",marker="o",linestyle='--')

# %%
#lineplot
x=[1,2,3,4,5]
y=[5,1,7,2,8]
plt.title("Line cchart")
plt.xlabel("x")
plt.ylabel("y")

plt.plot(x, y, color = "g",marker="o",linestyle='--',linewidth=3,markersize=10)

# %%
#lineplot
x=[1,2,3,4,5]
y=[5,1,7,2,8]
plt.title("Line cchart")
plt.xlabel("x")
plt.ylabel("y")
plt.plot(figsize=(150,200))

plt.plot(x, y, color = "g",marker="x",linestyle='--',linewidth=3,markersize=10)
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1]


plt.plot(x, y1, color = "red", marker = "o", linestyle = '--', linewidth = 3, markersize=6, label = 'line y1')
plt.plot(x, y2, color = "b", marker = "o", linestyle = '--', linewidth = 3, markersize=10, label = 'line y2')

plt.xlabel("x data axis")
plt.ylabel("y data axis")

plt.title("Multiple lines in one plot")
plt.legend()

plt.show()

# %%
x=np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot  #shift+tab
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
plt.plot(x,np.sin(x)) 
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x)) 
plt.plot(x,np.cos(x))  
plt.show() #removes metadata

# %%
plt.plot(x,np.sin(x),'--.') 
plt.plot(x,np.cos(x))  
plt.show() #removes metadata

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x))
plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

plt.subplot(2,2,3)
plt.plot(x,np.tan(x))

plt.subplot(2,2,4)
plt.plot(x,x**2)

plt.show()

# %%
plt.plot(x,np.sin(x),color='green')
plt.ylim(-1.5,1.5)
plt.xlim(1,5)
plt.axis('equal')
plt.show()

# %%
data=np.random.randn(1000)
data
# Out:
# array([ 8.14656534e-01,  6.32170039e-02,  2.40239948e-01,  1.56598357e+00,
#         1.24478431e+00, -2.38979160e-01,  1.65570296e+00, -8.29020384e-01,
#         2.54528629e-01,  2.17569081e+00,  4.96482059e-01, -2.02223479e+00,
#        -4.06022737e-01,  6.00458685e-01, -3.66334579e-01,  2.51488065e-01,
#         1.51162565e+00,  1.94668901e+00, -1.46113076e+00,  3.56854774e-01,
#         2.15285084e-01,  1.43306423e-01,  1.33835328e+00,  7.10903724e-02,
#         9.34408839e-01, -7.28012476e-01,  1.35736495e+00,  3.93426332e-01,
#        -1.89922960e+00,  2.86837616e-01,  1.72733318e-01, -1.73639902e+00,
#        -3.76561455e-01,  1.31485833e+00, -1.39851952e-01, -1.98211647e+00,
#        -1.37566210e-01,  8.85231477e-01, -5.86981708e-01, -3.69037635e-01,
#         1.66946016e-01,  4.64881245e-01,  1.86406577e+00,  4.06835791e-01,
#        -1.64011143e+00, -8.92131339e-01, -9.93804201e-01,  7.30595451e-01,
# ...

# %%
plt.hist(data,color='g')
# Out:
# (array([  6.,  36.,  72., 171., 235., 222., 152.,  78.,  25.,   3.]),
#  array([-3.13340297, -2.49785347, -1.86230397, -1.22675447, -0.59120497,
#          0.04434453,  0.67989403,  1.31544353,  1.95099303,  2.58654253,
#          3.22209203]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data,color='g',bins=5)
# Out:
# (array([ 42., 243., 457., 230.,  28.]),
#  array([-3.13340297, -1.86230397, -0.59120497,  0.67989403,  1.95099303,
#          3.22209203]),
#  <BarContainer object of 5 artists>)

# %%
import seaborn as sns
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df=sns.load_dataset('titanic')
df.sex.value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df=df.sex.value_counts().reset_index()

# %%
df
# Out:
#       sex  count
# 0    male    577
# 1  female    314

# %%
x=['male','female']
y=[577,314]

# %%
plt.bar(x,y,color='g')
# Out:
# <BarContainer object of 2 artists>

# %%
d1=np.random.normal(0,1,50000)
d2=np.random.normal(3,2,50000)

# %%
plt.hist([d1,d2],bins=20,color=['pink','g'],label=['d1','d2'])
plt.show()

# %%
langs=['C','Python','Java']
students=[20,40,110]

# %%
plt.pie(students,labels=langs,autopct = '%1.1f%%')
plt.title('Pie Chart')
plt.show()

# %%
explode=(0.0,0.1,0.2)
plt.pie(students,labels=langs,autopct = '%1.1f%%',explode=explode,shadow=True)
plt.title('Pie Chart')
plt.show()

# %%
#3-D plot

# %%
x=np.random.rand(20)
y=np.random.rand(20)
z=np.random.rand(20)

# %%
fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.scatter(x, y, z, c='g')

# %%
df1=sns.load_dataset('titanic')

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
plt.scatter(x=df1['age'],y=df1['fare'])
plt.show()

# %%
plt.hist(df1['fare'],color='g')
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df1['age'],color='b')
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
df1.boxplot(column='age')
# Out:
# <Axes: >

# %%
plt.violinplot(df1['fare'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x137e90950>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x137e19890>,
#  'cmins': <matplotlib.collections.LineCollection at 0x137e18610>,
#  'cbars': <matplotlib.collections.LineCollection at 0x137e05010>}

# %%
# Sample data
years = [2021, 2018, 2022, 2023, 2017]
category1 = [20, 25, 30, 28, 35]
category2 = [10, 15, 20, 18, 25]
category3 = [5, 8, 10, 9, 15]

# Create a area plot
plt.stackplot(years, category1, category2, category3, labels=['Category 1', 'Category 2', 'Category 3'],
              colors=['skyblue', 'y', 'orange'])

# Add labels and title
plt.xlabel("Years")
plt.ylabel("Values")
plt.title("Area Plot")
plt.legend()

plt.show()
